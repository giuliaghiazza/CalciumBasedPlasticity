# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.formatter.useoffset'] = False
import matplotlib.pyplot as plt
import nest
import numpy as np
import os
import re

from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
help(NESTCodeGeneratorUtils.generate_code_for)
# Out:
# Help on method generate_code_for in module pynestml.codegeneration.nest_code_generator_utils:
#
# generate_code_for(nestml_neuron_model: str, nestml_synapse_model: Union[str, NoneType] = None, module_name: Union[str, NoneType] = None, target_path: str = 'target', post_ports: Union[List[str], NoneType] = None, mod_ports: Union[List[str], NoneType] = None, logging_level: str = 'WARNING') method of builtins.type instance
#     Generate code for a given neuron and synapse model, passed as a string.
#     The neuron and synapse models can be passed directly as strings in NESTML syntax, or as filenames, in which case the NESTML model is loaded from the given filename.
#
#     Returns
#     -------
#     If a synapse is specified, returns a tuple (module_name, mangled_neuron_name, mangled_synapse_name) containing the names that can be used in ``nest.Install()``, ``nest.Create()`` and ``nest.Connect()`` calls. If no synapse is specified, returns a tuple (module_name, mangled_neuron_name).

# %%
import pynestml
pynestml.__version__
# Out:
# '7.0.2'

# %%
module_name, neuron_model_name, synapse_model_name = NESTCodeGeneratorUtils.generate_code_for(
     nestml_neuron_model="Neuron_new_eq.nestml",
    nestml_synapse_model="Sinapsi_vesicle_implemented.nestml", 
    module_name = "PW_module",
    post_ports=["post_spikes", ["rho_GB", "rho_GB"]],
    target_path = "target_stdp")
# Out:
# WARNING:root:PyGSL is not available. The stiffness test will be skipped.
# WARNING:root:Error when importing: No module named 'pygsl'
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [17,mhill_tononi_neuron_nestml, WARNING, [48:18;48:40]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [18,mhill_tononi_neuron_nestml, WARNING, [49:18;49:40]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [19,mhill_tononi_neuron_nestml, WARNING, [58:18;58:41]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# ...

# %% [markdown]
# # Now we can use the new module

# %% [markdown]
# ## Pre-before-Post

# %%
nest.ResetKernel()
nest.Install("PW_module")
duration = 10000 # ms
frequency = 10.0  # Hz
delta_t = 10.0  # ms

neuron_model = "mhill_tononi_neuron_nestml__with_stdp_nestml"
syn_model = "stdp_nestml__with_mhill_tononi_neuron_nestml"

pre_neuron = nest.Create(neuron_model, 1)
post_neuron = nest.Create(neuron_model, 1)


nest.SetStatus(pre_neuron, {"theta_d": 0.6, "theta_p": 0.74})
nest.SetStatus(post_neuron, {"theta_d": 0.6, "theta_p": 0.74})
nest.SetStatus(pre_neuron, {"tau_r_nmda": 10})
nest.SetStatus(post_neuron, {"tau_r_nmda": 10})
nest.SetStatus(pre_neuron, {"tau_d_nmda": 43})
nest.SetStatus(post_neuron, {"tau_d_nmda": 43})
nest.SetStatus(pre_neuron, {"gamma_p_GB": 216.2, "scala_vdcc": 1})
nest.SetStatus(post_neuron, {"gamma_p_GB": 216.2,"scala_vdcc": 1})
nest.SetStatus(pre_neuron, {"scala_nmda": 100000, "gamma_d_GB": 101.5})
nest.SetStatus(post_neuron, {"scala_nmda": 100000,"gamma_d_GB": 101.5})
nest.SetStatus(pre_neuron, {"gmax_d_AMPA": 0.5})
nest.SetStatus(post_neuron, {"gmax_p_AMPA": 1.0})
nest.SetStatus(pre_neuron, {"gmax_d_AMPA": 0.5})
nest.SetStatus(post_neuron, {"gmax_p_AMPA": 1.0})

wr = nest.Create("weight_recorder")
nest.SetDefaults(syn_model, {"weight_recorder": wr[0]})
receptors = nest.GetDefaults("mhill_tononi_neuron_nestml__with_stdp_nestml")["receptor_types"]
syn_spec = nest.CollocatedSynapses(
                                    {'synapse_model':syn_model,
                                     'receptor_type':receptors["AMPA"],
                                     }
                                    ,
                                   {
                                    'synapse_model':syn_model,
                                    'receptor_type': receptors["NMDA"],
                                       }
                                   )
nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec=syn_spec)

synapse = nest.GetConnections(pre_neuron, post_neuron)
nest.SetStatus(synapse, {"Wmax":50.0})

interval = 1000.0 / frequency
spike_times = np.arange(interval, duration, interval)
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t

else:
    delta_pre = -1 * delta_t
    delta_post = 0.0

    
syn_spec_spike_pre = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_pre,
                                    }
                                   )
syn_spec_spike_post = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_post,
                                    }
                                   )
    
nest.Connect(spike_generator, pre_neuron, "one_to_one", syn_spec=syn_spec_spike_pre)
nest.Connect(spike_generator, post_neuron, "one_to_one", syn_spec=syn_spec_spike_post)

sd_1 = nest.Create("spike_recorder")
sd_2 = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd_1)
nest.Connect(post_neuron, sd_2)

vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron)
nest.Connect(vm_post, post_neuron)

recorder = nest.Create( "multimeter",params={"interval": delta_t, "record_from": ["cai_CR", "effcai_GB", "rho_GB", "I_syn_vdcc", "I_syn_nmda", "I_ca_nmda", "AMPA_g_peak", "blocco_m", "g_nmda", "B_nmda", "A_nmda", "I_syn_ampa", "A_ampa", "B_ampa"]})
nest.Connect(recorder, post_neuron)

nest.Simulate(duration)

spikes_pre = sd_1.get(['events'][0])
spikes_post = sd_2.get(['events'][0])
#print(sd.events)
# Out:
# Dec 14 22:15:26 Install [Info]:
#     loaded module PW_module
#
# Dec 14 22:15:26 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Dec 14 22:15:26 NodeManager::prepare_nodes [Info]:
#     Preparing 9 nodes for simulation.
#
# Dec 14 22:15:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 9
#     Simulation time (ms): 10000
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
# ...
# Dec 14 22:15:26 SimulationManager::run [Info]:
#     Simulation finished.

# %%
pre_effcai = recorder.events["effcai_GB"]
pre_Ica_nmda = recorder.events["I_ca_nmda"]
pre_Isyn_vdcc = recorder.events["I_syn_vdcc"]
pre_ica_tot = pre_Ica_nmda + pre_Isyn_vdcc

# %%
ev       = recorder.get("events")
rho_GB      = ev["rho_GB"]
I_syn_vdcc = ev["I_syn_vdcc"]
cai_CR = ev["cai_CR"]
effcai_GB = ev["effcai_GB"]
blocco_m = ev["blocco_m"]
g_nmda = ev["g_nmda"]

max_rho = max(rho_GB)
max_I_vdcc = max(I_syn_vdcc)
max_cai_CR = max(cai_CR)
max_effcai_GB = max(effcai_GB)
max_blocco_m = max(blocco_m)
max_g_nmda = max(g_nmda)

print("Massimo valore di rho_GB:", max_rho)
print("Massimo valore di I_syn_vdcc:", max_I_vdcc)
print("Massimo valore di cai_CR:", max_cai_CR)
print("Massimo valore di effcai_GB:", max_effcai_GB)
print("Massimo valore di blocco_m:", max_blocco_m)
print("Massimo valore di g_nmda:", max_g_nmda)
# Out:
# Massimo valore di rho_GB: 0.4428660276478893
# Massimo valore di I_syn_vdcc: -6.002651603663325e-06
# Massimo valore di cai_CR: 70.01762251341607
# Massimo valore di effcai_GB: 0.8656095484960253
# Massimo valore di blocco_m: 0.009159278182258744
# Massimo valore di g_nmda: 1.6135556167743855e-05

# %%
ev       = recorder.get("events")
t        = ev["times"]
cai_CR      = ev["cai_CR"]
effcai_GB = ev["effcai_GB"]
rho_GB      = ev["rho_GB"]
I_syn_vdcc  = ev["I_syn_vdcc"]
I_syn_nmda = ev["I_syn_nmda"]
I_ca_nmda = ev["I_ca_nmda"]
AMPA_g_peak = ev["AMPA_g_peak"]
blocco_m = ev["blocco_m"]
g_nmda = ev["g_nmda"]


fig, ax = plt.subplots(12, figsize = (18,20))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("Post-synaptic neuron Potential")
ax[0].set_ylabel("Vm [mV]")
ax[0].legend()

ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[1].set_title("Post-synaptic neuron Potential")
ax[1].set_ylabel("Vm [mV]")
ax[1].set_xlim([7700,9500])
ax[1].legend()

ax[10].plot(recorder.events["times"], recorder.events["blocco_m"], color = "r", label = "Pre-synaptic blocco_m")
ax[10].set_title("Post-synaptic blocco_m")
ax[10].set_ylabel("blocco_m [-]")
ax[10].set_xlim([7700,9500])
ax[10].legend()

ax[11].plot(recorder.events["times"], recorder.events["g_nmda"], color = "b", label = "Pre-synaptic g_nmda")
ax[11].set_title("Post-synaptic g_nmda")
ax[11].set_ylabel("g_nmda [nS]")
ax[11].set_xlim([7700,9500])
ax[11].legend()

ax[2].plot(wr.events["times"], wr.events["weights"], color = 'r')
ax[2].set_title("STDP")
ax[2].set_ylabel("Weight [nS]")

ax[3].plot(recorder.events["times"], recorder.events["cai_CR"], color = "b", label = "Concentrazione interna calcio post")
ax[3].set_title("Concentrazione interna calcio post")
ax[3].set_ylabel("cai_CR [nmol/(dm**3)]")
ax[3].legend()

ax[4].plot(recorder.events["times"], recorder.events["effcai_GB"], color = "g", label = "effcai_GB")
ax[4].set_title("effcai_GB")
ax[4].set_ylabel("effcai_GB")
ax[4].legend()

ax[5].plot(recorder.events["times"], recorder.events["rho_GB"], color = "orange", label = "rho")
ax[5].set_title("rho")
ax[5].set_ylabel("rho_GB []")
ax[5].legend()

ax[6].plot(recorder.events["times"], recorder.events["I_syn_vdcc"], color = "r", label = "I_VDCC")
ax[6].set_title("I_VDCC")
ax[6].set_ylabel("I_syn_vdcc [pA]")
ax[6].legend()
ax[6].set_xlabel("Time [ms]")

ax[7].plot(recorder.events["times"], recorder.events["I_syn_nmda"], color = "b", label = "I_NMDA")
ax[7].set_title("I_NMDA")
ax[7].set_ylabel("I_syn_nmda [pA]")
ax[7].legend()
ax[7].set_xlabel("Time [ms]")

ax[8].plot(recorder.events["times"], recorder.events["I_ca_nmda"], color = "g", label = "I_Ca_NMDA")
ax[8].set_title("I_Ca_NMDA")
ax[8].set_ylabel("I_ca_nmda [pA]")
ax[8].legend()
ax[8].set_xlabel("Time [ms]")

ax[9].plot(recorder.events["times"], recorder.events["AMPA_g_peak"], color = "orange", label = "AMPA_g_peak")
ax[9].set_title("AMPA_g_peak")
ax[9].set_ylabel("AMPA_g_peak [nS]")
ax[9].legend()
ax[9].set_xlabel("Time [ms]")

fig.tight_layout()

# %%
plt.figure(figsize = (18,10))
plt.plot(recorder.events["times"], recorder.events["effcai_GB"])
#plt.xlim(4000.0, 5000.0)
plt.axhline(y=0.74, linestyle='--', color='orange', label='theta_p')
plt.axhline(y=0.6, linestyle='--', color='green', label='theta_d')
plt.ylabel("effcai_GB")
plt.xlabel("t [ms]")
plt.title("effcai_GB - Pre before Post")
plt.legend()
plt.show()

# %% [markdown]
# ## Post-before-Pre

# %%
nest.ResetKernel()
nest.Install("PW_module")
duration = 10000 # ms
frequency = 10.0  # Hz
delta_t = -10.0  # ms

neuron_model = "mhill_tononi_neuron_nestml__with_stdp_nestml"
syn_model = "stdp_nestml__with_mhill_tononi_neuron_nestml"

pre_neuron = nest.Create(neuron_model, 1)
post_neuron = nest.Create(neuron_model, 1)

nest.SetStatus(pre_neuron, {"rho_GB": 1})
nest.SetStatus(post_neuron, {"rho_GB": 1})
nest.SetStatus(pre_neuron, {"gmax_d_AMPA": 0.25})
nest.SetStatus(post_neuron, {"gmax_p_AMPA": 0.50})
nest.SetStatus(pre_neuron, {"gmax_d_AMPA": 0.25})
nest.SetStatus(post_neuron, {"gmax_p_AMPA": 0.50})
nest.SetStatus(post_neuron, {"tau_r_nmda": 10})
nest.SetStatus(pre_neuron, {"tau_d_nmda": 43})
nest.SetStatus(post_neuron, {"tau_d_nmda": 43})
nest.SetStatus(pre_neuron, {"theta_d": 0.6, "theta_p": 0.74})
nest.SetStatus(post_neuron, {"theta_d": 0.6, "theta_p": 0.74})
nest.SetStatus(pre_neuron, {"gamma_p_GB": 216.2, "scala_vdcc": 1})
nest.SetStatus(post_neuron, {"gamma_p_GB": 216.2,"scala_vdcc": 1})
nest.SetStatus(pre_neuron, {"scala_nmda": 100000, "gamma_d_GB": 101.5})
nest.SetStatus(post_neuron, {"scala_nmda": 100000,"gamma_d_GB": 101.5})


wr = nest.Create("weight_recorder")
nest.SetDefaults(syn_model, {"weight_recorder": wr[0]})
receptors = nest.GetDefaults("mhill_tononi_neuron_nestml__with_stdp_nestml")["receptor_types"]
syn_spec = nest.CollocatedSynapses(
                                    {'synapse_model':syn_model,
                                     'receptor_type':receptors["AMPA"],
                                     }
                                    ,
                                   {
                                    'synapse_model':syn_model,
                                    'receptor_type': receptors["NMDA"],
                                       }
                                   )
nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec=syn_spec)
synapse = nest.GetConnections(pre_neuron, post_neuron)
nest.SetStatus(synapse, {"Wmax":50.0})

interval = 1000.0 / frequency
spike_times = np.arange(interval, duration, interval)
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t

else:
    delta_pre = -1 * delta_t
    delta_post = 0.0

    
syn_spec_spike_pre = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_pre,
                                    }
                                   )
syn_spec_spike_post = nest.CollocatedSynapses(
                                    {'synapse_model':'static_synapse',
                                     'receptor_type': 3,
                                     'weight': 999.0,
                                     'delay': 1.0 + delta_post,
                                    }
                                   )
    
nest.Connect(spike_generator, pre_neuron, "one_to_one", syn_spec=syn_spec_spike_pre)
nest.Connect(spike_generator, post_neuron, "one_to_one", syn_spec=syn_spec_spike_post)

sd_1 = nest.Create("spike_recorder")
sd_2 = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd_1)
nest.Connect(post_neuron, sd_2)

vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron)
nest.Connect(vm_post, post_neuron)

recorder = nest.Create( "multimeter",params={"interval": -delta_t, "record_from": ["cai_CR", "effcai_GB", "rho_GB", "I_syn_vdcc", "I_syn_nmda", "I_ca_nmda", "AMPA_g_peak", "blocco_m", "g_nmda", "I_syn_ampa"]})
nest.Connect(recorder, post_neuron)

nest.Simulate(duration)

spikes_pre = sd_1.get(['events'][0])
spikes_post = sd_2.get(['events'][0])
#print(sd.events)
# Out:
# Dec 14 22:20:14 Install [Info]:
#     loaded module PW_module
#
# Dec 14 22:20:14 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Dec 14 22:20:14 NodeManager::prepare_nodes [Info]:
#     Preparing 9 nodes for simulation.
#
# Dec 14 22:20:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 9
#     Simulation time (ms): 10000
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
# ...
# Dec 14 22:20:14 SimulationManager::run [Info]:
#     Simulation finished.

# %%
ev       = recorder.get("events")
rho_GB      = ev["rho_GB"]
I_syn_vdcc = ev["I_syn_vdcc"]
cai_CR = ev["cai_CR"]
effcai_GB = ev["effcai_GB"]
blocco_m = ev["blocco_m"]
g_nmda = ev["g_nmda"]

max_rho = max(rho_GB)
max_I_vdcc = max(I_syn_vdcc)
max_cai_CR = max(cai_CR)
max_effcai_GB = max(effcai_GB)
max_blocco_m = max(blocco_m)
max_g_nmda = max(g_nmda)

print("Massimo valore di rho_GB:", max_rho)
print("Massimo valore di I_syn_vdcc:", max_I_vdcc)
print("Massimo valore di cai_CR:", max_cai_CR)
print("Massimo valore di effcai_GB:", max_effcai_GB)
print("Massimo valore di blocco_m:", max_blocco_m)
print("Massimo valore di g_nmda:", max_g_nmda)
# Out:
# Massimo valore di rho_GB: 1.0
# Massimo valore di I_syn_vdcc: -5.906182436155414e-06
# Massimo valore di cai_CR: 70.028450867493
# Massimo valore di effcai_GB: 0.8963388436833577
# Massimo valore di blocco_m: 0.4484504906083656
# Massimo valore di g_nmda: 8.935982339103368e-05

# %%
ev       = recorder.get("events")
t        = ev["times"]
cai_CR      = ev["cai_CR"]
effcai_GB = ev["effcai_GB"]
rho_GB      = ev["rho_GB"]
I_syn_vdcc  = ev["I_syn_vdcc"]
I_syn_vdcc  = ev["I_syn_vdcc"]


fig, ax = plt.subplots(12, figsize = (18,20))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("Post-synaptic neuron Potential")
ax[0].set_ylabel("Vm [mV]")
ax[0].legend()

ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[1].set_title("Post-synaptic neuron Potential")
ax[1].set_ylabel("Vm [mV]")
ax[1].set_xlim([7700,9500])
ax[1].legend()

ax[10].plot(recorder.events["times"], recorder.events["blocco_m"], color = "r", label = "Pre-synaptic blocco_m")
ax[10].set_title("Post-synaptic blocco_m")
ax[10].set_ylabel("blocco_m [-]")
ax[10].set_xlim([7700,9500])
ax[10].set_ylim([0, 0.01])
ax[10].legend()


ax[11].plot(recorder.events["times"], recorder.events["g_nmda"], color = "b", label = "Pre-synaptic g_nmda")
ax[11].set_title("Post-synaptic g_nmda")
ax[11].set_ylabel("g_nmda [nS]")
ax[11].set_xlim([7700,9500])
ax[11].set_ylim([0, 0.00005])
ax[11].legend()

ax[2].plot(wr.events["times"], wr.events["weights"], color = 'r')
ax[2].set_title("STDP")
ax[2].set_ylabel("Weight [nS]")

ax[3].plot(recorder.events["times"], recorder.events["cai_CR"], color = "b", label = "Concentrazione interna calcio post")
ax[3].set_title("Concentrazione interna calcio post")
ax[3].set_ylabel("cai_CR [nmol/(dm**3)]")
ax[3].legend()

ax[4].plot(recorder.events["times"], recorder.events["effcai_GB"], color = "g", label = "effcai_GB")
ax[4].set_title("effcai_GB")
ax[4].set_ylabel("effcai_GB")
ax[4].legend()

ax[5].plot(recorder.events["times"], recorder.events["rho_GB"], color = "orange", label = "rho")
ax[5].set_title("rho")
ax[5].set_ylabel("rho_GB []")
ax[5].legend()

ax[6].plot(recorder.events["times"], recorder.events["I_syn_vdcc"], color = "r", label = "I_VDCC")
ax[6].set_title("I_VDCC")
ax[6].set_ylabel("I_syn_vdcc [pA]")
#ax[6].set_xlim([7700,9500])
ax[6].set_ylim([-0.001, 0.0001])
ax[6].legend()
ax[6].set_xlabel("Time [ms]")

ax[7].plot(recorder.events["times"], recorder.events["I_syn_nmda"], color = "b", label = "I_NMDA")
ax[7].set_title("I_NMDA")
ax[7].set_ylabel("I_syn_nmda [pA]")
ax[7].set_ylim([-1, 0.1])
ax[7].legend()
ax[7].set_xlabel("Time [ms]")

ax[8].plot(recorder.events["times"], recorder.events["I_ca_nmda"], color = "g", label = "I_Ca_NMDA")
ax[8].set_title("I_Ca_NMDA")
ax[8].set_ylabel("I_ca_nmda [pA]")
ax[8].set_ylim([-0.1, 0.01])
ax[8].legend()
ax[8].set_xlabel("Time [ms]")

ax[9].plot(recorder.events["times"], recorder.events["AMPA_g_peak"], color = "orange", label = "AMPA_g_peak")
ax[9].set_title("AMPA_g_peak")
ax[9].set_ylabel("AMPA_g_peak [nS]")
ax[9].legend()
ax[9].set_xlabel("Time [ms]")

fig.tight_layout()

# %%
plt.figure(figsize = (18,10))
plt.plot(recorder.events["times"], recorder.events["effcai_GB"])
#plt.xlim(4000.0, 5000.0)
plt.axhline(y=0.74, linestyle='--', color='orange', label='theta_p')
plt.axhline(y=0.6, linestyle='--', color='green', label='theta_d')
plt.ylabel("effcai_GB")
plt.xlabel("t [ms]")
plt.title("effcai_GB - Post before Pre")
plt.legend()
plt.show()
